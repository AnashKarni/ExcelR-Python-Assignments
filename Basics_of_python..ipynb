# %% [markdown]
# #Exercise 1: Prime Numbers
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
# Take number from user
num = int(input("Enter a number: "))

# Check if number is greater than 1
if num > 1:
    # Check numbers from 2 to num-1
    for i in range(2, num):
        # If divisible, not prime
        if num % i == 0:
            print("Not a prime number")
            break
    else:
        # If loop completes without break
        print("Prime number")
else:
    # Numbers <= 1 are not prime
    print("Not a prime number")
# Out:
# Enter a number:  5
# Prime number

# %% [markdown]
# Exercise 2: Product of Random Numbers
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random    # This allows the computer to pick random numbers

# Pick a random number between 1 and 10
num1 = random.randint(1, 10)
# Pick another random number between 1 and 10
num2 = random.randint(1, 10)
# Multiply both numbers to get the correct answer
correct_answer = num1 * num2

# Ask the user a question and take their answer as input
# f"" is used to insert the numbers inside the question
user_answer = int(input(f"What is {num1} x {num2}?"))

# Check if the user's answer is correct
if user_answer == correct_answer:
     # If correct, show this message
    print("Correct! Well done.")
else:
     # If wrong, show the correct answer
    print(f"Incorrect. The right answer was {correct_answer}.")
# Out:
# What is 1 x 3? 4
# Incorrect. The right answer was 3.

# %% [markdown]
# Exercise 3: Squares of Even/Odd Numbers
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
# This program prints squares of EVEN numbers from 100 to 200

for n in range(100, 201):  # Loop from 100 to 200
    if n % 2 == 0:         # Check if number is even
        print(n, "square is", n*n)  # Print number and its square
# Out:
# 100 square is 10000
# 102 square is 10404
# 104 square is 10816
# 106 square is 11236
# 108 square is 11664
# 110 square is 12100
# 112 square is 12544
# 114 square is 12996
# 116 square is 13456
# 118 square is 13924
# 120 square is 14400
# 122 square is 14884
# 124 square is 15376
# 126 square is 15876
# 128 square is 16384
# 130 square is 16900
# 132 square is 17424
# 134 square is 17956
# 136 square is 18496
# 138 square is 19044
# 140 square is 19600
# 142 square is 20164
# 144 square is 20736
# 146 square is 21316
# 148 square is 21904
# 150 square is 22500
# 152 square is 23104
# 154 square is 23716
# 156 square is 24336
# 158 square is 24964
# 160 square is 25600
# 162 square is 26244
# 164 square is 26896
# 166 square is 27556
# 168 square is 28224
# 170 square is 28900
# 172 square is 29584
# 174 square is 30276
# 176 square is 30976
# 178 square is 31684
# 180 square is 32400
# 182 square is 33124
# 184 square is 33856
# 186 square is 34596
# 188 square is 35344
# 190 square is 36100
# 192 square is 36864
# 194 square is 37636
# 196 square is 38416
# 198 square is 39204
# 200 square is 40000

# %% [markdown]
# Exercise 4:
# ✅ Problem Statement (Question): Hospital Billing System
# A hospital charges its patients based on the following:
# •	Room charges per day: ₹2,000
# •	Doctor consultation fee (flat): ₹1,500
# •	Lab test charges: Based on the number of tests taken. Each test costs ₹300
# •	Medicine charges: Total cost of medicines provided
# •	Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
# Write a Python program to calculate the final bill for a patient who:
# •	Stayed for 4 days
# •	Had 3 lab tests
# •	Had medicine charges of ₹2,400

# %%
# Room charge: 2000 per day for 4 days
room_total = 2000 * 4

# Doctor fee (fixed)
doctor_fee = 1500

# Lab test: 300 per test for 3 tests
lab_total = 300 * 3

# Medicine cost
medicine_total = 2400

# Calculate total bill before discount
total_bill = room_total + doctor_fee + lab_total + medicine_total

# Check if discount applies
if total_bill > 10000:
    discount = total_bill * 0.10   # 10% discount
    final_bill = total_bill - discount
else:
    final_bill = total_bill

# Print final bill
print("Final Bill is:", final_bill)
# Out:
# Final Bill is: 11520.0
